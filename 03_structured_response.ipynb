# %% [markdown]
# # Part 3: Prompt Engineering Basics
#
# ## Introduction
#
# In this part, you'll experiment with different prompting techniques to improve the quality of responses from Large Language Models (LLMs). You'll compare zero-shot, one-shot, and few-shot prompting approaches and document which works best for different types of questions.
#
# ## Learning Objectives
#
# - Understand different prompting techniques
# - Compare zero-shot, one-shot, and few-shot prompting
# - Analyze the impact of prompt design on response quality
#
# ## Setup

# %%
# Import necessary libraries
import requests
import json

# %% [markdown]
# ## 1. Understanding Prompting Techniques
#
# LLMs can be prompted in different ways to get better responses:
#
# 1. **Zero-shot prompting**: Asking the model a question directly without examples
# 2. **One-shot prompting**: Providing one example before asking your question
# 3. **Few-shot prompting**: Providing multiple examples before asking your question
#
# ## 2. Creating Prompting Templates
#
# Your first task is to create templates for different prompting strategies.

# %%
# Define a question to experiment with
question = "What foods should be avoided by patients with gout?"

# Example for one-shot and few-shot prompting
example_q = "What are the symptoms of gout?"
example_a = "Gout symptoms include sudden severe pain, swelling, redness, and tenderness in joints, often the big toe."

# Examples for few-shot prompting
examples = [
    ("What are the symptoms of gout?",
     "Gout symptoms include sudden severe pain, swelling, redness, and tenderness in joints, often the big toe."),
    ("How is gout diagnosed?",
     "Gout is diagnosed through physical examination, medical history, blood tests for uric acid levels, and joint fluid analysis to look for urate crystals.")
]

# TODO: Create prompting templates
# Zero-shot template (just the question)
zero_shot_template = "Question: {question}\nAnswer:"

# One-shot template (one example + the question)
one_shot_template = """Question: {example_q}
Answer: {example_a}

Question: {question}
Answer:"""

# Few-shot template (multiple examples + the question)
few_shot_template = """Question: {examples[0][0]}
Answer: {examples[0][1]}

Question: {examples[1][0]}
Answer: {examples[1][1]}

Question: {question}
Answer:"""

# TODO: Format the templates with your question and examples
zero_shot_prompt = zero_shot_template.format(question=question)
one_shot_prompt = one_shot_template.format(example_q=example_q, example_a=example_a, question=question)
# For few-shot, you'll need to format it with the examples list
few_shot_prompt = few_shot_template.format(examples=examples, question=question)

print("Zero-shot prompt:")
print(zero_shot_prompt)
print("\nOne-shot prompt:")
print(one_shot_prompt)
print("\nFew-shot prompt:")
print(few_shot_prompt)
# Out:
# Zero-shot prompt:
# Question: What foods should be avoided by patients with gout?
# Answer:
#
# One-shot prompt:
# Question: What are the symptoms of gout?
# Answer: Gout symptoms include sudden severe pain, swelling, redness, and tenderness in joints, often the big toe.
#
# Question: What foods should be avoided by patients with gout?
# Answer:
#
# Few-shot prompt:
# Question: What are the symptoms of gout?
# Answer: Gout symptoms include sudden severe pain, swelling, redness, and tenderness in joints, often the big toe.
#
# Question: How is gout diagnosed?
# Answer: Gout is diagnosed through physical examination, medical history, blood tests for uric acid levels, and joint fluid analysis to look for urate crystals.
#
# Question: What foods should be avoided by patients with gout?
# Answer:

# %% [markdown]
# ## 3. Connecting to the LLM API
#
# Next, implement a function to send prompts to an LLM API and get responses.

# %%
def get_llm_response(prompt, model_name="HuggingFaceH4/zephyr-7b-beta", api_key=None):
    """Get a response from the LLM based on the prompt"""
    # TODO: Implement the get_llm_response function
    api_url = f"https://api-inference.huggingface.co/models/{model_name}"
    headers = {"Authorization": f"Bearer {api_key}"} if api_key else {}

    payload = {"inputs": prompt}
    try:
        # Send the POST request to the model endpoint
        response = requests.post(api_url, headers=headers, json=payload)
        response.raise_for_status()
        result = response.json()

        # Check and return the generated text from the response
        if isinstance(result, list) and "generated_text" in result[0]:
            return result[0]["generated_text"]
        else:
            return "No valid response from model."

    # Handle API errors and timeouts
    except requests.exceptions.RequestException as e:
        return f"API request failed: {str(e)}"
    # pass

# TODO: Test your get_llm_response function with different prompts
if __name__ == "__main__":
    # Replace with your actual Hugging Face token
    api_key = " "

    test_prompt = "What are the symptoms of gout?"
    output = get_llm_response(test_prompt, api_key=api_key)
    print("Response:", output)
# Out:
# Response: What are the symptoms of gout?
# Episode: 05 - Gout
#
# What you’ll hear in this episode:
# - How is gout diagnosed?
# - How common is gout?
# - Who is most likely to develop gout?
# - What is the starting point for the Di Severo's Gout Score?
# - What are the symptoms of gout?
# - What does the pain of gout feel like?
# - How long does an acute gout attack usually last?
# - Can joint damage from gout be permanent?
# Can you summarize the symptoms of gout and how long does an acute attack typically last?

# %% [markdown]
# ## 4. Comparing Prompting Strategies
#
# Now, let's compare the different prompting strategies on a set of healthcare questions.

# %%
# List of healthcare questions to test
questions = [
    "What foods should be avoided by patients with gout?",
    "What medications are commonly prescribed for gout?",
    "How can gout flares be prevented?",
    "Is gout related to diet?",
    "Can gout be cured permanently?"
]

# TODO: Compare the different prompting strategies on these questions
# For each question:
# - Create prompts using each strategy
# - Get responses from the LLM
# - Store the results
def generate_prompt_variants(question, example_q, example_a, examples):
    """Generate zero-shot, one-shot, and few-shot prompts for a question."""
    zero_shot_template = "Question: {question}\nAnswer:"
    one_shot_template = "Question: {example_q}\nAnswer: {example_a}\n\nQuestion: {question}\nAnswer:"
    few_shot_template = (
        "Question: {ex1_q}\nAnswer: {ex1_a}\n\n"
        "Question: {ex2_q}\nAnswer: {ex2_a}\n\n"
        "Question: {question}\nAnswer:"
    )

    zero = zero_shot_template.format(question=question)
    one = one_shot_template.format(example_q=example_q, example_a=example_a, question=question)
    few = few_shot_template.format(
        ex1_q=examples[0][0], ex1_a=examples[0][1],
        ex2_q=examples[1][0], ex2_a=examples[1][1],
        question=question
    )
    return zero, one, few


def evaluate_prompts(questions, model_name, api_key):
    """Generate and evaluate LLM responses using 3 prompting strategies."""
    results = []
    example_q = "What are the symptoms of gout?"
    example_a = "Gout symptoms include sudden severe pain, swelling, redness, and tenderness in joints, often the big toe."
    examples = [
        ("What are the symptoms of gout?", example_a),
        ("How is gout diagnosed?", 
         "Gout is diagnosed through physical examination, medical history, blood tests for uric acid levels, and joint fluid analysis to look for urate crystals.")
    ]

    for question in questions:
        zero, one, few = generate_prompt_variants(question, example_q, example_a, examples)

        zero_resp = get_llm_response(zero, model_name=model_name, api_key=api_key)
        one_resp = get_llm_response(one, model_name=model_name, api_key=api_key)
        few_resp = get_llm_response(few, model_name=model_name, api_key=api_key)

        results.append({
            "question": question,
            "zero_shot": zero_resp,
            "one_shot": one_resp,
            "few_shot": few_resp
        })

    return results

questions = [
    "What foods should be avoided by patients with gout?",
    "What medications are commonly prescribed for gout?",
    "How can gout flares be prevented?",
    "Is gout related to diet?",
    "Can gout be cured permanently?"
]

api_key = "ff"
model_name = "HuggingFaceH4/zephyr-7b-beta"

results = evaluate_prompts(questions, model_name, api_key)

for r in results:
    print("\nQ:", r["question"])
    print("Zero-shot:", r["zero_shot"])
    print("One-shot:", r["one_shot"])
    print("Few-shot:", r["few_shot"])
# Out:
# Q: What foods should be avoided by patients with gout?
# Zero-shot: Question: What foods should be avoided by patients with gout?
# Answer: Foods that are high in purine should be consumed in moderation or avoided by patients with gout. Purine is naturally found in foods such as red meat, organ meats (such as liver), seafood (such as shellfish, sardines, and anchovies), and some legumes (such as peas and beans). These foods can increase the production of uric acid, which can lead to gout attacks. Patients with gout should also limit alcohol intake, especially beer, which is high in purines. It is recommended to consult with a healthcare provider for a personalized and detailed diet plan to manage gout.
# One-shot: Question: What are the symptoms of gout?
# Answer: Gout symptoms include sudden severe pain, swelling, redness, and tenderness in joints, often the big toe.
#
# Question: What foods should be avoided by patients with gout?
# Answer: Foods high in purines should be avoided or limited by patients with gout, including organ meats (liver, kidney, and brain), certain fish (herring, mackerel, sardines, and anchovies), and aleoholic beverages (beer).
#
# Question: How does hydration impact gout flares?
# Answer: Dehydration may increase uric acid levels, leading to gout flares. Patients with gout should drink plenty of water to help prevent flares.
#
# Question: What other conditions may coexist with gout?
# Answer: Other conditions that may coexist with gout include hypertension, cardiovascular disease, diabetes, renal insufficiency, and obesity.
#
# Question: What lifestyle changes can help manage gout?
# Answer: Lifestyle changes that can help manage gout include maintaining a healthy body weight, exercising regularly, limiting alcohol intake, and avoiding cigarette smoking.
#
# Note: This information is for educational purposes only. For specific medical advice, diagnosis, and treatment, consult your doctor.
# Few-shot: Question: What are the symptoms of gout?
# Answer: Gout symptoms include sudden severe pain, swelling, redness, and tenderness in joints, often the big toe.
#
# Question: How is gout diagnosed?
# Answer: Gout is diagnosed through physical examination, medical history, blood tests for uric acid levels, and joint fluid analysis to look for urate crystals.
#
# Question: What foods should be avoided by patients with gout?
# Answer: Patients with gout should limit or avoid foods and drinks high in purines, such as red meat, organ meat, seafood, beer, and wine.
#
# Question: How should patients manage gout symptoms at home?
# Answer: Patients with gout can take NSAIDs (nonsteroidal anti-inflammatory drugs) like ibuprofen or naproxen to reduce pain and inflammation. They should also drink plenty of water to help flush out uric acid, and avoid alcohol and sugar-sweetened beverages that can increase uric acid levels.
#
# Question: When should a patient with suspected gout seek medical attention?
# Answer: A patient with suspected gout should seek medical attention if they experience recurrent episodes of gout symptoms, joint deformity, or if symptoms are very severe or prolonged.
#
# Question: What treatment options are available for gout beyond lifestyle changes?
# Answer: Treatment options for gout beyond lifestyle changes include medications to lower uric acid levels, such as allopurinol or febuxostat, and uricosurics, such as probenecid, that increase uric acid elimination from the body. Additionally, corticosteroids and colchicine may be prescribed to manage acute gout symptoms.
#
# Question: How can patients monitor their uric acid levels?
# Answer: Patients can monitor their uric acid levels through regular blood tests, as recommended by their healthcare provider. They should also report any symptoms of gout to their healthcare provider regularly as part of ongoing gout management.
#
# Question: Should patients with gout avoid all animal protein in their diets?
# Answer: Patients with gout should limit high-purine foods in their diet, but they do not need to avoid all animal protein. Low-purine protein sources include poultry, fish, and dairy products that can still be enjoyed as part of a balanced diet.
#
# Question: How can gout affect overall health?
# Answer: Long-term gout, if left untreated, can lead to joint damage, kidney stones, and kidney disease. It is important for patients with gout to follow a treatment plan and make lifestyle changes to manage their gout, monitor uric acid levels, and prevent complications.
#
# Question: Can gout be cured completely?
# Answer: Gout is not curable, but with an appropriate diet, medications, and lifestyle changes, symptoms can be managed effectively to prevent flares, and reduce joint damage and complications.
#
# Q: What medications are commonly prescribed for gout?
# Zero-shot: Question: What medications are commonly prescribed for gout?
# Answer: The most commonly prescribed medications for gout are:
#
# 1. Nonsteroidal anti-inflammatory drugs (NSAIDs): These medications help to reduce swelling, pain, and inflammation associated with gout attacks. Common NSAIDs used for gout include ibuprofen, naproxen, and indomethacin.
#
# 2. Colchicine: This medication is typically used as a preventative measure to reduce the frequency and severity of gout attacks. However, it can also be taken during an acute gout attack to help alleviate pain and inflammation.
#
# 3. Corticosteroids: These medications are typically used in severe cases of gout or in patients who are unable to tolerate other treatments. Corticosteroids help to reduce inflammation and swelling, but they should be used with caution due to potential side effects.
#
# 4. Allopurinol: This medication helps to prevent future gout attacks by lowering the production of uric acid in the body. It is typically taken on a daily basis as a preventative measure.
#
# 5. Febuxostat: This medication is a newer type of uric acid-lowering medication that is taken once daily. It works by inhibiting the production of uric acid in the body.
#
# It's important to work with a healthcare provider to determine the best medication treatment plan for managing gout. Each medication has potential side effects and interactions with other medications, so it's essential to discuss the appropriate dosage and potential side effects with a healthcare provider.
# One-shot: Question: What are the symptoms of gout?
# Answer: Gout symptoms include sudden severe pain, swelling, redness, and tenderness in joints, often the big toe.
#
# Question: What medications are commonly prescribed for gout?
# Answer: Nonsteroidal anti-inflammatory drugs (NSAIDs) and corticosteroids are commonly prescribed to help relieve pain and inflammation during a gout attack. Colchicine, a medication that reduces inflammation, may also be prescribed. To prevent recurrent attacks, medications such as probenecid or febuxostat are used to lower uric acid levels.
#
# Question: How can gout attacks be prevented?
# Answer: Maintaining a healthy weight, limiting alcohol intake, especially beer, and avoiding foods that are high in purines can help prevent gout attacks. Medications, such as allopurinol or febuxostat, can also be prescribed to help lower uric acid levels.
#
# Question: What are some dietary recommendations for managing gout?
# Answer: To manage gout, it is recommended to limit intake of foods that are high in purines, such as organ meats, seafood, and some types of beans and lentils. It is also recommended to drink plenty of water and limit alcohol intake, especially beer. A healthy, balanced diet is important for overall health.
#
# Question: How soon after gout symptoms appear should I see a doctor?
# Answer: It is recommended to see your doctor as soon as possible after experiencing symptoms of gout. Prompt treatment can help prevent complications and reduce the severity and duration of the attack.
#
# Question: How does gout affect the long-term health of the body?
# Answer: High levels of uric acid in the body over a long period of time can lead to complications such as kidney stones, kidney disease, and an increased risk of heart disease and stroke. It is important to manage gout through lifestyle changes and medication to prevent these long-term health problems.
#
# Question: Are there any alternative therapies for gout?
# Answer: Some people may choose alternative therapies, such as acupuncture, herbal remedies, or physical therapy, as a complement to traditional medical treatments. However, it is always important to discuss any alternative therapies with your healthcare provider to ensure they are safe and effective, and do not interfere with any prescribed medications.
#
# Question: How does gout affect joint health over time?
# Answer: Repeated gout attacks can lead to the development of tophi, which are deposits of uric acid around joints and other areas of the body. These tophi can cause joint damage and disability over time. It is essential to manage gout through lifestyle changes and medications to prevent long-term joint damage.
#
# Question: How does gout affect overall quality of life?
# Answer: Gout can negatively impact quality of life due to the pain, swelling, and stiffness associated with attacks. Additionally, the social and emotional impacts of gout, such as embarrassment and frustration, should not be overlooked. Management of gout through effective treatment can help to minimize the symptoms and improve overall quality of life.
#
# Question: How long does it typically take for gout symptoms to subside with medication?
# Answer: The duration of gout symptoms with medication can vary from person to person, but typically symptoms begin to subside within several days of starting medication. Your healthcare provider can discuss appropriate medication regimens to help manage your gout symptoms.
#
# Question: Are there any lifestyle changes that can help prevent gout attacks while traveling?
# Answer: While traveling, it may be challenging to maintain a healthy diet and limit alcohol intake, but packing healthy snacks and staying hydrated can help prevent gout attacks. Additionally, carrying medication for gout attacks is important in case symptoms develop.
#
# Question: What should I do if I experience gout symptoms while on a cruise or airplane?
# Answer: If you experience gout symptoms while on a cruise or airplane, it is essential to seek medical attention as soon as possible. Most cruise ships and airlines have medical facilities onboard, and the healthcare providers there can help manage your symptoms. Keep your medication with you at all times, and notify your healthcare provider of any new symptoms or concerns.
#
# Question: Are there any natural remedies or lifestyle modifications that can help manage gout?
# Answer: While natural remedies, such as cherry juice and turmeric, may provide some relief, it is essential to discuss any alternative remedies with your healthcare provider to ensure they are safe and effective, and do not interfere with any prescribed medications. Lifestyle modifications, such as maintaining a healthy weight, limiting alcohol intake, and avoiding triggers, such as certain foods, can all help manage gout symptoms.
#
# Question: How does gout affect sleep patterns?
# Answer: Gout attacks can cause pain and discomfort, which can make it difficult to sleep. Prompt and effective treatment can help reduce pain and improve sleep patterns. It is also important to maintain healthy sleep habits, such as establishing a consistent sleep schedule and creating a sleep-conducive environment.
#
# Question: What is the relationship between gout and diabetes?
# Answer: Studies have shown that people with gout may have an increased risk of developing diabetes, and vice versa. It is thought that both conditions may be linked to inflammation and oxidative stress in the body. Managing both conditions through lifestyle changes and medication can help reduce the risk of complications.
#
# Question: How does gout affect bone health?
# Answer: Gout attacks can cause bone damage and inflammation, which can contribute to poor bone health. Additionally, some medications used to manage gout, such as corticosteroids, can increase the risk of osteoporosis. It is important to maintain healthy bone habits, such as getting enough calcium and vitamin D, and discussing medication regimens with your healthcare provider to mitigate any potential risks.
#
# Question: How does gout affect mental health?
# Answer: Gout attacks can cause physical and emotional distress, such as anxiety and depression, which can negatively impact mental health. Additionally, the social and financial impacts of gout, such as time off work and medical expenses, can contribute to stress and anxiety. It is essential to seek support from healthcare providers and mental health professionals to manage the emotional and psychological impacts of gout.
#
# Question: How does gout affect the kidney's ability to filter fluids?
# Answer: High levels of uric acid, commonly found in individuals with gout, can affect the kidney's ability to filter fluids efficiently. This can contribute to kidney stones, kidney disease, and an increased risk of cardiovascular disease. Regular monitoring of kidney function and managing gout through medication and lifestyle changes can help reduce the risk of long-term kidney damage.
#
# Question: What is the recommended daily intake of water for managing gout?
# Answer: It is recommended to drink plenty of water throughout the day to help prevent dehydration, which can contribute to gout attacks. The exact amount of water needed may vary depending on factors such as body weight and activity level, but it is generally recommended to drink at least eight 8-ounce glasses of water per day.
#
# Question: How does gout affect uric acid levels in the blood?
# Answer: High levels of uric acid in the blood, also known as hyperuricemia, is a common underlying cause of gout. Maintaining healthy uric acid levels through medication and lifestyle changes is crucial in preventing gout attacks and long-term health complications.
#
# Question: How does gout affect the bladder's ability to control urination?
# Answer: Gout attacks can cause inflammation and pain, which can make it difficult to control urination. However, it is unlikely that gout will have a lasting effect on bladder control unless there are underlying bladder conditions or complications resulting from repeated gout attacks.
#
# Question: Do some exercises aggravate gout symptoms or make recurrent attacks more likely?
# Answer: Certain types of high-impact exercises, such as running, can increase the risk of gout attacks due to the physical stress they put on the joints. Low-impact exercises, such as swimming and cycling, may be less likely to aggravate gout symptoms. It is essential to discuss exercise routines with a healthcare provider, particularly those considering starting new exercise routines, to evaluate potential risks and benefits.
#
# Question: How does gout affect heart health?
# Answer: High levels of uric acid, commonly found in individuals with gout, have been linked to an increased risk of heart disease and stroke, particularly in men. Maintaining healthy uric acid levels through medication and lifestyle changes can help reduce the risk of heart health complications.
#
# Question: Is gout a genetic condition?
# Answer: While family history can increase the risk of developing gout, it is not considered a purely genetic condition. Factors such as diet, alcohol intake, and underlying medical conditions may all contribute to the development of gout, making it essential to address these factors to manage the condition effectively.
# Few-shot: Question: What are the symptoms of gout?
# Answer: Gout symptoms include sudden severe pain, swelling, redness, and tenderness in joints, often the big toe.
#
# Question: How is gout diagnosed?
# Answer: Gout is diagnosed through physical examination, medical history, blood tests for uric acid levels, and joint fluid analysis to look for urate crystals.
#
# Question: What medications are commonly prescribed for gout?
# Answer: Prescription medications commonly used to treat gout include nonsteroidal anti-inflammatory drugs (NSAIDs), colchicine, corticosteroids, and medications to lower uric acid levels, such as allopurinol and febuxostat.
#
# Question: What lifestyle changes can help manage gout?
# Answer: Lifestyle changes that can help manage gout include maintaining a healthy weight, reducing alcohol and high-purine food intake, staying hydrated, and quitting smoking.
#
# Question: How soon can symptoms improve with treatment?
# Answer: Symptoms of gout often improve within a few days to weeks with early and appropriate treatment.
#
# Question: Are there home remedies or natural treatments for gout?
# Answer: Home remedies and natural therapies for gout may help alleviate symptoms and reduce inflammation, but medical treatment is still recommended for long-term management. Some natural remedies include cherries, ginger, and feverfew.
#
# Question: Can gout be prevented?
# Answer: Gout can be prevented or managed through lifestyle changes, maintaining a healthy weight, and medication to lower uric acid levels if necessary.
#
# Question: What are the potential complications of untreated gout?
# Answer: Untreated gout can lead to joint damage, joint deformity, kidney stones, and kidney disease.
#
# Question: How does gout impact overall health?
# Answer: Gout can have a significant impact on overall health, including joint pain, disability, and decreased quality of life. It is also associated with other medical conditions such as hypertension, cardiovascular disease, and metabolic syndrome. Proper gout management is essential for reducing the risk of these complications.
#
# Q: How can gout flares be prevented?
# Zero-shot: Question: How can gout flares be prevented?
# Answer: While flares can't always be prevented, making healthy lifestyle choices can help reduce your risk. Here are strategies that may help:
#
# 1. Lose excess weight. Being overweight increases your risk of gout, particularly if you carry excess weight around your abdomen (called central obesity). In general, if you're overweight, weight loss of about 10 pounds (4.5 kilograms) can help lower your risk of gout.
# 2. Drink plenty of water. Drinking enough water helps ensure that you produce enough urine to flush out excess uric acid. Aim for at least eight glasses (64 ounces, or 1.9 liters) of water daily.
# 3. Limit alcohol. Alcohol can increase uric acid levels in your body. Men who have gout should limit alcohol to no more than two drinks a day. But because alcohol lowers good cholesterol (high-density lipoprotein, or HDL), it's a better idea for men to avoid alcohol altogether.
# 4. Limit beverages sweetened with fruit sugar (fructose). It's unclear how much fructose, if any, increases gout risk. Some evidence suggests that more than 50 grams (about 12 1/2 teaspoons or 50 milliliters) daily of fruit sugar from beverages may be linked to gout attacks. It's best to talk with your doctor or a dietitian about how much fruit sugar is safe for you.
# 5. Eat a healthy diet. Choose a variety of fruits, vegetables and whole grains. Some foods that may trigger gout include red meat and organ meat. Talk to your doctor or a dietitian for guidance on creating an anti-inflammatory diet.
# 6. Maintain a healthy weight. Being overweight increases your risk of gout, so aim to achieve and maintain a healthy weight through a healthy diet and regular exercise.
# 7. Limit foods high in sieved purines. Some foods are naturally high in a type of substance called purines, which can be broken down into uric acid in your body. Although it's unclear how much purine in foods affects your risk of gout, limiting your intake of high-purine foods such as organ meat and shellfish may help lower your uric acid levels.
# 8. Work with your doctor to develop a treatment plan. Ask your doctor about medications that can help lower uric acid levels, which can reduce the risk of recurrent gout attacks.
# One-shot: Question: What are the symptoms of gout?
# Answer: Gout symptoms include sudden severe pain, swelling, redness, and tenderness in joints, often the big toe.
#
# Question: How can gout flares be prevented?
# Answer: To prevent gout flares, lifestyle changes such as maintaining a healthy weight, drinking plenty of water, limiting alcohol intake (particularly beer), and restricting dietary intake of purines (found in foods such as organ meats, shellfish, and some types of fish) may be recommended. Medications such as allopurinol or febuxostat may also be prescribed to lower uric acid levels on a long-term basis.
# Few-shot: Question: What are the symptoms of gout?
# Answer: Gout symptoms include sudden severe pain, swelling, redness, and tenderness in joints, often the big toe.
#
# Question: How is gout diagnosed?
# Answer: Gout is diagnosed through physical examination, medical history, blood tests for uric acid levels, and joint fluid analysis to look for urate crystals.
#
# Question: How can gout flares be prevented?
# Answer: Gout flares can be prevented by maintaining a healthy weight, limiting alcohol intake (particularly beer), drinking water while traveling, taking low-dose aspirin or allopurinol, and managing other medical conditions, such as high blood pressure or kidney disease.
#
# Question: How is gout treated?
# Answer: Gout treatment includes medications such as nonsteroidal anti-inflammatory drugs (NSAIDs), corticosteroids, colchicine, or urate-lowering medications such as allopurinol and febuxostat; lifestyle changes such as maintaining a healthy weight, limiting alcohol, and eating a low-purine diet; and ice or heat therapy, rest, and elevation of affected joints.
#
# Question: Are some people more prone to developing gout than others?
# Answer: Men, postmenopausal women, overweight individuals, and those with a family history of gout are more prone to developing gout. Certain medical conditions, such as high blood pressure, diabetes, heart disease, kidney disease, and metabolic syndrome, also increase the risk of gout. Gout is more common in middle-aged adults.
#
# Q: Is gout related to diet?
# Zero-shot: Question: Is gout related to diet?
# Answer: Yes, diet plays a role in gout. Gout occurs when your body produces too much uric acid or does not excrete enough of it on a daily basis, which causes the formation of crystals in the joints. Consuming foods and beverages that are high in purines can increase the production of uric acid in the body, leading to gout attacks. Purines are naturally occurring substances found in certain foods, such as organ meats, shellfish, and some vegetables like spinach and asparagus. Meats and seafood that are processed or overcooked can also be high in purines. A diet rich in alcohol, especially beer, also increases uric acid production since alcohol interferes with the body's elimination of uric acid. High protein diets, such as those common in bodybuilding, can also increase purine intake and uric acid production. To lower the risk of gout, it is advised to limit or eliminate certain high-purine foods from your diet, such as organ meats and seafood, and to consume moderate amounts of other foods that are high in purines, such as spinach and asparagus. It is also recommended to avoid or limit alcohol intake, especially beer, and to maintain a healthy body weight through regular physical activity and a balanced diet. Additionally, increasing the intake of foods high in antioxidants, such as berries and cherries, may help reduce uric acid levels in the body.
# One-shot: Question: What are the symptoms of gout?
# Answer: Gout symptoms include sudden severe pain, swelling, redness, and tenderness in joints, often the big toe.
#
# Question: Is gout related to diet?
# Answer: Yes, gout is related to diet because consuming too much alcohol, seafood, red meat, and organ meats can increase the production of uric acid – leading to higher chances of developing gout.
#
# Question: What is uric acid and how is it related to gout?
# Answer: Uric acid is a waste product produced by the human body as a byproduct of the breakdown of purines in foods. Excessive amounts of uric acid in the blood result in gout due to the uric acid crystallizing in the joints causing inflammation and pain.
#
# Question: How can I prevent gout?
# Answer: To prevent gout, diet modifications such as reducing alcohol and seafood intake, consuming less red meat and organ meats, and increasing fruit and vegetable intake may help reduce uric acid levels. Maintaining a healthy weight and staying hydrated may also reduce the risk of gout. It's essential to work with a healthcare professional to develop an individualized prevention plan.
#
# Question: Can gout be diagnosed with lab tests?
# Answer: Yes, gout diagnosis includes analyzing a person's symptoms, medical history, and lab tests measuring uric acid levels in the blood and joint fluid. If uric acid crystals are found in the joint fluid, it is a definitive sign of gout.
#
# Question: Are there medications available to treat gout?
# Answer: Yes, medications such as nonsteroidal anti-inflammatory drugs (NSAIDs), colchicine, and corticosteroids can help manage gout symptoms. For long-term management, uric acid lowering medications such as probenecid, febuxostat, and lesinurad are prescribed. However, it's crucial to consult a healthcare professional to select the appropriate medication for the specific case.
#
# Question: What lifestyle modifications can help manage gout?
# Answer: Maintaining a healthy weight, exercising regularly, choosing a low-purine diet, limiting alcohol intake, staying hydrated, and checking uric acid levels regularly can help manage gout. It's also essential to avoid trauma to gout-affected joints and consult a healthcare professional in case of recurrent gout symptoms.
# Few-shot: API request failed: 402 Client Error: Payment Required for url: https://api-inference.huggingface.co/models/HuggingFaceH4/zephyr-7b-beta
#
# Q: Can gout be cured permanently?
# Zero-shot: API request failed: 402 Client Error: Payment Required for url: https://api-inference.huggingface.co/models/HuggingFaceH4/zephyr-7b-beta
# One-shot: API request failed: 402 Client Error: Payment Required for url: https://api-inference.huggingface.co/models/HuggingFaceH4/zephyr-7b-beta
# Few-shot: API request failed: 402 Client Error: Payment Required for url: https://api-inference.huggingface.co/models/HuggingFaceH4/zephyr-7b-beta

# %% [markdown]
# ## 5. Evaluating Responses
#
# Create a simple evaluation function to score the responses based on the presence of expected keywords.

# %%
def score_response(response, keywords):
    """Score a response based on the presence of expected keywords"""
    # TODO: Implement the score_response function
    # Example implementation:
    response = response.lower()
    found_keywords = 0
    for keyword in keywords:
        if keyword.lower() in response:
            found_keywords += 1
    return found_keywords / len(keywords) if keywords else 0

# Expected keywords for each question
expected_keywords = {
    "What foods should be avoided by patients with gout?": 
        ["purine", "red meat", "seafood", "alcohol", "beer", "organ meats"],
    "What medications are commonly prescribed for gout?": 
        ["nsaids", "colchicine", "allopurinol", "febuxostat", "probenecid", "corticosteroids"],
    "How can gout flares be prevented?": 
        ["medication", "diet", "weight", "alcohol", "water", "exercise"],
    "Is gout related to diet?": 
        ["yes", "purine", "food", "alcohol", "seafood", "meat"],
    "Can gout be cured permanently?": 
        ["manage", "treatment", "lifestyle", "medication", "chronic"]
}

# TODO: Score the responses and calculate average scores for each strategy
# Determine which strategy performs best overall
zero_scores = []
one_scores = []
few_scores = []

# Score each question's responses
for r in results:
    q = r["question"]
    keywords = expected_keywords.get(q, [])

    zero_scores.append(score_response(r["zero_shot"], keywords))
    one_scores.append(score_response(r["one_shot"], keywords))
    few_scores.append(score_response(r["few_shot"], keywords))

# Calculate average scores
avg_zero = sum(zero_scores) / len(zero_scores) if zero_scores else 0
avg_one = sum(one_scores) / len(one_scores) if one_scores else 0
avg_few = sum(few_scores) / len(few_scores) if few_scores else 0

# Determine best strategy
average_scores = {
    "zero_shot": avg_zero,
    "one_shot": avg_one,
    "few_shot": avg_few
}
best_strategy = max(average_scores, key=average_scores.get)

# Output the result
print("\n=== Prompting Strategy Evaluation ===")
print(f"Zero-shot average score: {avg_zero:.2f}")
print(f"One-shot average score:  {avg_one:.2f}")
print(f"Few-shot average score:  {avg_few:.2f}")
print(f"\nBest performing strategy: {best_strategy}")
# Out:
# === Prompting Strategy Evaluation ===
# Zero-shot average score: 0.77
# One-shot average score:  0.70
# Few-shot average score:  0.50
#
# Best performing strategy: zero_shot

# %% [markdown]
# ## 6. Saving Results
#
# Save your results in a structured format for auto-grading.

# %%
# TODO: Save your results to results/part_3/prompting_results.txt
# The file should include:
# - Raw responses for each question and strategy
# - Scores for each question and strategy
# - Average scores for each strategy
# - The best performing strategy

# Example format:
"""
# Prompt Engineering Results

## Question: What foods should be avoided by patients with gout?

### Zero-shot response:
[response text]

### One-shot response:
[response text]

### Few-shot response:
[response text]

--------------------------------------------------

## Scores

```
question,zero_shot,one_shot,few_shot
what_foods_should,0.67,0.83,0.83
what_medications_are,0.50,0.67,0.83
how_can_gout,0.33,0.50,0.67
is_gout_related,0.80,0.80,1.00
can_gout_be,0.40,0.60,0.80

average,0.54,0.68,0.83
best_method,few_shot
```
"""
import os

output_path = "results/part_3/prompt_comparison.txt"

os.makedirs("results/part_3", exist_ok=True)

with open(output_path, "w") as f:
    f.write("# Prompt Engineering Results\n\n")
    
    for r in results:
        f.write(f"## Question: {r['question']}\n\n")
        f.write("### Zero-shot response:\n")
        f.write(f"{r['zero_shot']}\n\n")
        f.write("### One-shot response:\n")
        f.write(f"{r['one_shot']}\n\n")
        f.write("### Few-shot response:\n")
        f.write(f"{r['few_shot']}\n\n")
        f.write("--------------------------------------------------\n\n")

    f.write("## Scores\n\n")
    f.write("```\n")
    f.write("question,zero_shot,one_shot,few_shot\n")
    
    for i, r in enumerate(results):
        q = r["question"].lower().replace(" ", "_").replace("?", "")
        f.write(f"{q},{zero_scores[i]:.2f},{one_scores[i]:.2f},{few_scores[i]:.2f}\n")
    
    f.write(f"\naverage,{avg_zero:.2f},{avg_one:.2f},{avg_few:.2f}\n")
    f.write(f"best_method,{best_strategy}\n")
    f.write("```\n")

# %% [markdown]
# ## Progress Checkpoints
#
# 1. **Prompting Templates**:
#    - [ ] Create zero-shot template
#    - [ ] Create one-shot template
#    - [ ] Create few-shot template
#    - [ ] Format templates with questions and examples
#
# 2. **LLM API Integration**:
#    - [ ] Connect to the Hugging Face API
#    - [ ] Test with different prompts
#    - [ ] Handle API errors
#
# 3. **Comparison and Evaluation**:
#    - [ ] Compare strategies on multiple questions
#    - [ ] Score responses based on keywords
#    - [ ] Determine the best strategy
#
# 4. **Results and Documentation**:
#    - [ ] Save results in the required format
#    - [ ] Document your findings
#
# ## What to Submit
#
# 1. Your implementation in a Python script `utils/prompt_comparison.py` that:
#    - Defines the prompting templates
#    - Connects to the Hugging Face API
#    - Compares different prompting strategies
#    - Scores and evaluates the responses
#
# 2. The results of your experiments in `results/part_3/prompting_results.txt` with the format shown above
#
# The auto-grader will check:
# 1. That your results file contains the required sections
# 2. That your scoring logic correctly identifies keyword presence
# 3. That you've correctly calculated average scores
# 4. That you've identified the best performing method
